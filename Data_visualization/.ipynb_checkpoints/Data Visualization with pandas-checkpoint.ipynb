# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %% [markdown]
# ## generating 1000 random number so we can use them in our plots

# %%
df = pd.DataFrame(randn(1000),index=pd.date_range('2019-06-07',periods=1000),columns=['value'])
## here what i am doing is getting 1000 random numbers and converting them into a dataframe and the indexing them
## with dates and named the column name as value
ts = pd.Series(randn(1000),index=pd.date_range('2019-06-07',periods=1000))
## here what i am doing is getting 1000 random numbers and converting them into a Series and the indexing them
## with dates

# %%
df.head()
# Out:
#                value
# 2019-06-07 -0.458888
# 2019-06-08 -0.248568
# 2019-06-09 -0.551500
# 2019-06-10 -0.626827
# 2019-06-11 -1.888020

# %%
ts.head()
# Out:
# 2019-06-07    0.563167
# 2019-06-08    2.620044
# 2019-06-09    0.760237
# 2019-06-10    1.195800
# 2019-06-11   -1.214821
# Freq: D, dtype: float64

# %% [markdown]
# ## plotting just to see how the data is

# %%
df.plot()
## it is plotting a scatter plot with x-axis as the index and y-axis as the column
# Out:
# <Axes: >

# %%
ts.plot()
## it is plotting a scatter plot with x-axis as the index and y-axis as the column
# Out:
# <Axes: >

# %%
df = df.cumsum()
df
# Out:
#                 value
# 2019-06-07  -0.458888
# 2019-06-08  -0.707456
# 2019-06-09  -1.258956
# 2019-06-10  -1.885783
# 2019-06-11  -3.773802
# ...               ...
# 2022-02-26 -15.737333
# 2022-02-27 -16.463282
# 2022-02-28 -16.554603
# 2022-03-01 -16.295427
# 2022-03-02 -14.973580
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (10,5))
# Out:
# <Axes: >

# %%
ts = ts.cumsum()
ts
## cummulative sum:- it is the summation of the current element with the previous element
# Out:
# 2019-06-07     0.563167
# 2019-06-08     3.183211
# 2019-06-09     3.943448
# 2019-06-10     5.139249
# 2019-06-11     3.924427
#                 ...
# 2022-02-26    -9.619221
# 2022-02-27    -8.494036
# 2022-02-28    -9.165828
# 2022-03-01    -9.766007
# 2022-03-02   -11.075128
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot(figsize = (10,5))
## we can see hoe the graph is change from the above graph after we have applied cummulative sum
# Out:
# <Axes: >

# %%
plt.plot(ts)
## we can see here that with the same data we are able to plot two similar graphs with different approaches
## ts.plot() this is using the pandas plot and plt.plot(ts) this is using the matplotlib library

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8),title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind='bar')
## here the black thing in x-axis it is nothing but the dates are clumsy hence we got this.
# Out:
# <Axes: >

# %%
## we will drop the categorical column
df1 = iris.drop(['species'],axis=1)

# %%
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df1.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df1.iloc[0].plot(kind='bar')
# Out:
# <Axes: >

# %%
## loading the titanic dataset
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind="bar")
# Out:
# <Axes: >

# %%
df2 = pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
df2.head()
# Out:
#           a         b         c         d
# 0  1.122380 -0.463963 -1.749975  0.294665
# 1  0.553206  0.660179  1.003361  0.111610
# 2 -1.269147  0.200898  0.765651  0.123824
# 3  0.084013 -0.835373 -0.508707 -0.032158
# 4 -0.199254  1.618445 -1.578409  0.491643

# %%
df2.plot.bar()
## from the below graph we can say that there are columns for each row that is clearly been shown in the below graph
# Out:
# <Axes: >

# %%
df2.plot(kind='bar')
# Out:
# <Axes: >

# %%
df2.plot(kind='barh')
## here we can see that there is a difference comapred to the above graph it is that the graph here is horizontal
## this is because we have used barh instead of using just bar.
# Out:
# <Axes: >

# %%
## Histograms

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['sepal_length'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot(kind='hist',stacked=False,bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_ex = pd.DataFrame([0,0,1,2,2,3,4,8,10])

# %%
df_ex
# Out:
#     0
# 0   0
# 1   0
# 2   1
# 3   2
# 4   2
# 5   3
# 6   4
# 7   8
# 8  10

# %%
df_ex.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris['sepal_width'].diff()
## it will give the difference between the current element and the previous element
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind='hist', stacked=False,bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## plot a graph and show the variation in the fare price

# %%
df_ex1 = titanic['fare']

# %%
df_ex1.head()
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: fare, dtype: float64

# %%
plt.plot(df_ex1)
plt.xlabel('Passenger')
plt.ylabel('Fare Price')
plt.title('Variation of Fare')
plt.show()

# %% [markdown]
# ## Plot a histogram to show surived and dead

# %%
titanic['survived'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_iris = iris.drop(['species'],axis=1)

# %%
df_iris.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df_iris.diff().hist(color='b',alpha=0.5,figsize=(10,5))
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df_iris.plot.scatter(x='sepal_length',y='petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
## here the c cordinate will be represneted by the intensity of the the dots in the scatter plots
## the darker it is the value is higher and vice-versa
df_iris.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width')
## in the below graph we can see that the lower the sepal length and petal length the higher is the sepal width
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
## This is used to change the size of the dot in a scatter plot
df_iris.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=80)
## here we can see that the size of the dots in the scatter plot increse
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# ## Hexbin this is very similar to scatter plot but instead of dots it will draw hexagons

# %%
df_iris.plot.hexbin(x='sepal_length',y='petal_length',gridsize=50,C='sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
d = df_iris.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize=(5,5))
# Out:
# <Axes: ylabel='0'>

# %%
d = df_iris.head(3)

# %%
d = d.T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots=True,figsize = (10,10))
# Out:
# array([<Axes: ylabel='0'>, <Axes: ylabel='1'>, <Axes: ylabel='2'>],
#       dtype=object)

# %%
d.plot.pie(subplots=True,figsize=(20,20),fontsize=20,autopct='%.2f')
# Out:
# array([<Axes: ylabel='0'>, <Axes: ylabel='1'>, <Axes: ylabel='2'>],
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df_iris,figsize=(8,8),diagonal='kde',color='b')
plt.show()

# %% [markdown]
# ## to check the distribution of a particular column

# %%
df_iris['petal_length'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## Covert the data into and draw the graph

# %%
df_iris.plot(legend=True,figsize=(10,5),logy=True)
# Out:
# <Axes: >

# %%
df_iris.plot(subplots=True,sharex=False,sharey=False,layout=(2,3),figsize=(16,8))
# Out:
# array([[<Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >]], dtype=object)
