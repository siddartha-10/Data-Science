# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import xgboost as xgb
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('pima-indians-diabetes.csv')
data.head()
# Out:
#    Number of times pregnant  Plasma glucose concentration  ...  Age  Is Diabetic
# 0                         6                           148  ...   50            1
# 1                         1                            85  ...   31            0
# 2                         8                           183  ...   32            1
# 3                         1                            89  ...   21            0
# 4                         0                           137  ...   33            1
#
# [5 rows x 9 columns]

# %%
data.columns
# Out:
# Index(['Number of times pregnant', 'Plasma glucose concentration',
#        'Diastolic blood pressure (mm Hg)', 'Triceps skinfold thickness (mm)',
#        '2-Hour serum insulin (mu U/ml)',
#        'Body mass index (weight in kg/(height in m)^2)',
#        'Diabetes pedigree function', 'Age', 'Is Diabetic'],
#       dtype='object')

# %%
cols = ['Plasma glucose concentration',
       'Diastolic blood pressure (mm Hg)', 'Triceps skinfold thickness (mm)',
       '2-Hour serum insulin (mu U/ml)',
       'Body mass index (weight in kg/(height in m)^2)',
       'Diabetes pedigree function', 'Age']

# %%
for col in cols:
    data[col] = data[col].replace(0,np.nan)

# %%
data.isna().sum()
# Out:
# Number of times pregnant                            0
# Plasma glucose concentration                        5
# Diastolic blood pressure (mm Hg)                   35
# Triceps skinfold thickness (mm)                   227
# 2-Hour serum insulin (mu U/ml)                    374
# Body mass index (weight in kg/(height in m)^2)     11
# Diabetes pedigree function                          0
# Age                                                 0
# Is Diabetic                                         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Number of times pregnant                        768 non-null    int64
#  1   Plasma glucose concentration                    763 non-null    float64
#  2   Diastolic blood pressure (mm Hg)                733 non-null    float64
#  3   Triceps skinfold thickness (mm)                 541 non-null    float64
#  4   2-Hour serum insulin (mu U/ml)                  394 non-null    float64
#  5   Body mass index (weight in kg/(height in m)^2)  757 non-null    float64
#  6   Diabetes pedigree function                      768 non-null    float64
#  7   Age                                             768 non-null    int64
#  8   Is Diabetic                                     768 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 54.1 KB

# %%
data.shape
# Out:
# (768, 9)

# %%
data.describe()
# Out:
#        Number of times pregnant  ...  Is Diabetic
# count                768.000000  ...   768.000000
# mean                   3.845052  ...     0.348958
# std                    3.369578  ...     0.476951
# min                    0.000000  ...     0.000000
# 25%                    1.000000  ...     0.000000
# 50%                    3.000000  ...     0.000000
# 75%                    6.000000  ...     1.000000
# max                   17.000000  ...     1.000000
#
# [8 rows x 9 columns]

# %%
# imputing the missing values
data['Plasma glucose concentration']=data['Plasma glucose concentration'].fillna(data['Plasma glucose concentration'].mode()[0])
data['Diastolic blood pressure (mm Hg)']=data['Diastolic blood pressure (mm Hg)'].fillna(data['Diastolic blood pressure (mm Hg)'].mode()[0])
data['Triceps skinfold thickness (mm)']=data['Triceps skinfold thickness (mm)'].fillna(data['Triceps skinfold thickness (mm)'].mean())
data['2-Hour serum insulin (mu U/ml)']=data['2-Hour serum insulin (mu U/ml)'].fillna(data['2-Hour serum insulin (mu U/ml)'].mean())
data['Body mass index (weight in kg/(height in m)^2)']=data['Body mass index (weight in kg/(height in m)^2)'].fillna(data['Body mass index (weight in kg/(height in m)^2)'].mean())

# %%
data.describe()
# Out:
#        Number of times pregnant  ...  Is Diabetic
# count                768.000000  ...   768.000000
# mean                   3.845052  ...     0.348958
# std                    3.369578  ...     0.476951
# min                    0.000000  ...     0.000000
# 25%                    1.000000  ...     0.000000
# 50%                    3.000000  ...     0.000000
# 75%                    6.000000  ...     1.000000
# max                   17.000000  ...     1.000000
#
# [8 rows x 9 columns]

# %%
data.isna().sum()
# clearly now there are no null values
# Out:
# Number of times pregnant                          0
# Plasma glucose concentration                      0
# Diastolic blood pressure (mm Hg)                  0
# Triceps skinfold thickness (mm)                   0
# 2-Hour serum insulin (mu U/ml)                    0
# Body mass index (weight in kg/(height in m)^2)    0
# Diabetes pedigree function                        0
# Age                                               0
# Is Diabetic                                       0
# dtype: int64

# %%
# separting the features and the target variable
X = data.drop(columns='Is Diabetic',axis=1)
y = data['Is Diabetic']

# %%
# we can see that the values are lot bigger and it's better to standarize so we will scale them
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
scaled_data = ss.fit_transform(X)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
x_train,x_test,y_train,y_test = train_test_split(scaled_data,y,test_size=0.3,random_state=42)

# %%
model = XGBClassifier(objective='binary:logistic')
model.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = model.predict(x_train)
preiction_y = [round(value) for value in y_pred]
accuracy = accuracy_score(preiction_y,y_train)
accuracy
# the accuracy here is the acuracy for training dataset
# Out:
# 1.0

# %%
y_pred = model.predict(x_test)
preiction_y = [round(value) for value in y_pred]
accuracy = accuracy_score(preiction_y,y_test)
accuracy
# the accuracy here is the acuracy for testing dataset
# Out:
# 0.7142857142857143

# %%
x_test[0]
# Out:
# array([ 0.63994726, -0.77251205, -1.18156252,  0.43784695,  0.40547846,
#         0.22451019, -0.1264714 ,  0.83038113])

# %%
# now to increase the accuracy we will do hyperparamaeter tuning
grid_param = {
    'learning_rate':[1,0.5,0.1,0.01,0.001],
    'max_depth':[5,10,15,20],
    'n_estimators':[10,50,100,200]
}

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(XGBClassifier(objective='binary:logistic'),param_grid=grid_param,verbose=3)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [CV 1/5] END learning_rate=1, max_depth=5, n_estimators=10;, score=0.787 total time=   0.0s
# [CV 2/5] END learning_rate=1, max_depth=5, n_estimators=10;, score=0.769 total time=   0.0s
# [CV 3/5] END learning_rate=1, max_depth=5, n_estimators=10;, score=0.748 total time=   0.0s
# [CV 4/5] END learning_rate=1, max_depth=5, n_estimators=10;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=1, max_depth=5, n_estimators=10;, score=0.776 total time=   0.0s
# [CV 1/5] END learning_rate=1, max_depth=5, n_estimators=50;, score=0.769 total time=   0.0s
# [CV 2/5] END learning_rate=1, max_depth=5, n_estimators=50;, score=0.759 total time=   0.0s
# [CV 3/5] END learning_rate=1, max_depth=5, n_estimators=50;, score=0.766 total time=   0.0s
# [CV 4/5] END learning_rate=1, max_depth=5, n_estimators=50;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=1, max_depth=5, n_estimators=50;, score=0.738 total time=   0.0s
# [CV 1/5] END learning_rate=1, max_depth=5, n_estimators=100;, score=0.796 total time=   0.0s
# [CV 2/5] END learning_rate=1, max_depth=5, n_estimators=100;, score=0.731 total time=   0.0s
# [CV 3/5] END learning_rate=1, max_depth=5, n_estimators=100;, score=0.757 total time=   0.0s
# [CV 4/5] END learning_rate=1, max_depth=5, n_estimators=100;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=1, max_depth=5, n_estimators=100;, score=0.757 total time=   0.0s
# [CV 1/5] END learning_rate=1, max_depth=5, n_estimators=200;, score=0.787 total time=   0.0s
# [CV 2/5] END learning_rate=1, max_depth=5, n_estimators=200;, score=0.750 total time=   0.0s
# [CV 3/5] END learning_rate=1, max_depth=5, n_estimators=200;, score=0.757 total time=   0.0s
# [CV 4/5] END learning_rate=1, max_depth=5, n_estimators=200;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=1, max_depth=5, n_estimators=200;, score=0.748 total time=   0.0s
# [CV 1/5] END learning_rate=1, max_depth=10, n_estimators=10;, score=0.787 total time=   0.0s
# [CV 2/5] END learning_rate=1, max_depth=10, n_estimators=10;, score=0.704 total time=   0.0s
# [CV 3/5] END learning_rate=1, max_depth=10, n_estimators=10;, score=0.748 total time=   0.0s
# [CV 4/5] END learning_rate=1, max_depth=10, n_estimators=10;, score=0.720 total time=   0.0s
# [CV 5/5] END learning_rate=1, max_depth=10, n_estimators=10;, score=0.729 total time=   0.0s
# [CV 1/5] END learning_rate=1, max_depth=10, n_estimators=50;, score=0.778 total time=   0.0s
# [CV 2/5] END learning_rate=1, max_depth=10, n_estimators=50;, score=0.694 total time=   0.0s
# [CV 3/5] END learning_rate=1, max_depth=10, n_estimators=50;, score=0.748 total time=   0.0s
# [CV 4/5] END learning_rate=1, max_depth=10, n_estimators=50;, score=0.720 total time=   0.0s
# [CV 5/5] END learning_rate=1, max_depth=10, n_estimators=50;, score=0.748 total time=   0.0s
# [CV 1/5] END learning_rate=1, max_depth=10, n_estimators=100;, score=0.787 total time=   0.0s
# [CV 2/5] END learning_rate=1, max_depth=10, n_estimators=100;, score=0.694 total time=   0.0s
# [CV 3/5] END learning_rate=1, max_depth=10, n_estimators=100;, score=0.738 total time=   0.0s
# [CV 4/5] END learning_rate=1, max_depth=10, n_estimators=100;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=1, max_depth=10, n_estimators=100;, score=0.757 total time=   0.0s
# [CV 1/5] END learning_rate=1, max_depth=10, n_estimators=200;, score=0.796 total time=   0.0s
# [CV 2/5] END learning_rate=1, max_depth=10, n_estimators=200;, score=0.685 total time=   0.0s
# [CV 3/5] END learning_rate=1, max_depth=10, n_estimators=200;, score=0.738 total time=   0.0s
# [CV 4/5] END learning_rate=1, max_depth=10, n_estimators=200;, score=0.701 total time=   0.0s
# [CV 5/5] END learning_rate=1, max_depth=10, n_estimators=200;, score=0.738 total time=   0.0s
# [CV 1/5] END learning_rate=1, max_depth=15, n_estimators=10;, score=0.750 total time=   0.0s
# [CV 2/5] END learning_rate=1, max_depth=15, n_estimators=10;, score=0.750 total time=   0.0s
# [CV 3/5] END learning_rate=1, max_depth=15, n_estimators=10;, score=0.776 total time=   0.0s
# [CV 4/5] END learning_rate=1, max_depth=15, n_estimators=10;, score=0.692 total time=   0.0s
# [CV 5/5] END learning_rate=1, max_depth=15, n_estimators=10;, score=0.710 total time=   0.0s
# [CV 1/5] END learning_rate=1, max_depth=15, n_estimators=50;, score=0.750 total time=   0.0s
# [CV 2/5] END learning_rate=1, max_depth=15, n_estimators=50;, score=0.731 total time=   0.0s
# [CV 3/5] END learning_rate=1, max_depth=15, n_estimators=50;, score=0.748 total time=   0.0s
# [CV 4/5] END learning_rate=1, max_depth=15, n_estimators=50;, score=0.701 total time=   0.0s
# [CV 5/5] END learning_rate=1, max_depth=15, n_estimators=50;, score=0.748 total time=   0.0s
# [CV 1/5] END learning_rate=1, max_depth=15, n_estimators=100;, score=0.750 total time=   0.0s
# [CV 2/5] END learning_rate=1, max_depth=15, n_estimators=100;, score=0.759 total time=   0.0s
# [CV 3/5] END learning_rate=1, max_depth=15, n_estimators=100;, score=0.757 total time=   0.0s
# [CV 4/5] END learning_rate=1, max_depth=15, n_estimators=100;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=1, max_depth=15, n_estimators=100;, score=0.757 total time=   0.0s
# [CV 1/5] END learning_rate=1, max_depth=15, n_estimators=200;, score=0.750 total time=   0.0s
# [CV 2/5] END learning_rate=1, max_depth=15, n_estimators=200;, score=0.750 total time=   0.0s
# [CV 3/5] END learning_rate=1, max_depth=15, n_estimators=200;, score=0.738 total time=   0.0s
# [CV 4/5] END learning_rate=1, max_depth=15, n_estimators=200;, score=0.692 total time=   0.0s
# [CV 5/5] END learning_rate=1, max_depth=15, n_estimators=200;, score=0.729 total time=   0.0s
# [CV 1/5] END learning_rate=1, max_depth=20, n_estimators=10;, score=0.750 total time=   0.0s
# [CV 2/5] END learning_rate=1, max_depth=20, n_estimators=10;, score=0.750 total time=   0.0s
# [CV 3/5] END learning_rate=1, max_depth=20, n_estimators=10;, score=0.776 total time=   0.0s
# [CV 4/5] END learning_rate=1, max_depth=20, n_estimators=10;, score=0.692 total time=   0.0s
# [CV 5/5] END learning_rate=1, max_depth=20, n_estimators=10;, score=0.710 total time=   0.0s
# [CV 1/5] END learning_rate=1, max_depth=20, n_estimators=50;, score=0.750 total time=   0.0s
# [CV 2/5] END learning_rate=1, max_depth=20, n_estimators=50;, score=0.731 total time=   0.0s
# [CV 3/5] END learning_rate=1, max_depth=20, n_estimators=50;, score=0.748 total time=   0.0s
# [CV 4/5] END learning_rate=1, max_depth=20, n_estimators=50;, score=0.701 total time=   0.0s
# [CV 5/5] END learning_rate=1, max_depth=20, n_estimators=50;, score=0.748 total time=   0.0s
# [CV 1/5] END learning_rate=1, max_depth=20, n_estimators=100;, score=0.750 total time=   0.0s
# [CV 2/5] END learning_rate=1, max_depth=20, n_estimators=100;, score=0.759 total time=   0.0s
# [CV 3/5] END learning_rate=1, max_depth=20, n_estimators=100;, score=0.757 total time=   0.0s
# [CV 4/5] END learning_rate=1, max_depth=20, n_estimators=100;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=1, max_depth=20, n_estimators=100;, score=0.757 total time=   0.0s
# [CV 1/5] END learning_rate=1, max_depth=20, n_estimators=200;, score=0.750 total time=   0.0s
# [CV 2/5] END learning_rate=1, max_depth=20, n_estimators=200;, score=0.750 total time=   0.0s
# [CV 3/5] END learning_rate=1, max_depth=20, n_estimators=200;, score=0.738 total time=   0.0s
# [CV 4/5] END learning_rate=1, max_depth=20, n_estimators=200;, score=0.692 total time=   0.0s
# [CV 5/5] END learning_rate=1, max_depth=20, n_estimators=200;, score=0.729 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.778 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.778 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.748 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.701 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.729 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.787 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.750 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.785 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.701 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=0.787 total time=   0.1s
# [CV 2/5] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=0.750 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=0.776 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=0.701 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=0.710 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=5, n_estimators=200;, score=0.778 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=5, n_estimators=200;, score=0.769 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=5, n_estimators=200;, score=0.776 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=5, n_estimators=200;, score=0.710 total time=   0.1s
# [CV 5/5] END learning_rate=0.5, max_depth=5, n_estimators=200;, score=0.720 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=10, n_estimators=10;, score=0.759 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=10, n_estimators=10;, score=0.722 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=10, n_estimators=10;, score=0.785 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=10, n_estimators=10;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=10, n_estimators=10;, score=0.757 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=10, n_estimators=50;, score=0.787 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=10, n_estimators=50;, score=0.731 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=10, n_estimators=50;, score=0.776 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=10, n_estimators=50;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=10, n_estimators=50;, score=0.757 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=10, n_estimators=100;, score=0.796 total time=   0.1s
# [CV 2/5] END learning_rate=0.5, max_depth=10, n_estimators=100;, score=0.741 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=10, n_estimators=100;, score=0.766 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=10, n_estimators=100;, score=0.720 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=10, n_estimators=100;, score=0.757 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=10, n_estimators=200;, score=0.787 total time=   0.1s
# [CV 2/5] END learning_rate=0.5, max_depth=10, n_estimators=200;, score=0.731 total time=   0.1s
# [CV 3/5] END learning_rate=0.5, max_depth=10, n_estimators=200;, score=0.757 total time=   0.1s
# [CV 4/5] END learning_rate=0.5, max_depth=10, n_estimators=200;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=10, n_estimators=200;, score=0.748 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=15, n_estimators=10;, score=0.787 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=15, n_estimators=10;, score=0.731 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=15, n_estimators=10;, score=0.776 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=15, n_estimators=10;, score=0.729 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=15, n_estimators=10;, score=0.729 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=15, n_estimators=50;, score=0.778 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=15, n_estimators=50;, score=0.731 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=15, n_estimators=50;, score=0.738 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=15, n_estimators=50;, score=0.738 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=15, n_estimators=50;, score=0.738 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=15, n_estimators=100;, score=0.769 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=15, n_estimators=100;, score=0.722 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=15, n_estimators=100;, score=0.738 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=15, n_estimators=100;, score=0.729 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=15, n_estimators=100;, score=0.757 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=15, n_estimators=200;, score=0.759 total time=   0.1s
# [CV 2/5] END learning_rate=0.5, max_depth=15, n_estimators=200;, score=0.722 total time=   0.1s
# [CV 3/5] END learning_rate=0.5, max_depth=15, n_estimators=200;, score=0.738 total time=   0.2s
# [CV 4/5] END learning_rate=0.5, max_depth=15, n_estimators=200;, score=0.729 total time=   0.1s
# [CV 5/5] END learning_rate=0.5, max_depth=15, n_estimators=200;, score=0.738 total time=   0.1s
# [CV 1/5] END learning_rate=0.5, max_depth=20, n_estimators=10;, score=0.787 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=20, n_estimators=10;, score=0.731 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=20, n_estimators=10;, score=0.776 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=20, n_estimators=10;, score=0.729 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=20, n_estimators=10;, score=0.729 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=20, n_estimators=50;, score=0.778 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=20, n_estimators=50;, score=0.731 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=20, n_estimators=50;, score=0.738 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=20, n_estimators=50;, score=0.738 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=20, n_estimators=50;, score=0.738 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=20, n_estimators=100;, score=0.769 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=20, n_estimators=100;, score=0.722 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=20, n_estimators=100;, score=0.738 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=20, n_estimators=100;, score=0.729 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=20, n_estimators=100;, score=0.757 total time=   0.1s
# [CV 1/5] END learning_rate=0.5, max_depth=20, n_estimators=200;, score=0.759 total time=   0.1s
# [CV 2/5] END learning_rate=0.5, max_depth=20, n_estimators=200;, score=0.722 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=20, n_estimators=200;, score=0.738 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=20, n_estimators=200;, score=0.729 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=20, n_estimators=200;, score=0.738 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=0.778 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=0.787 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=0.757 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=0.692 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=0.729 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.815 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.731 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.757 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.720 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.729 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.787 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.731 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.757 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.738 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.729 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.787 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.759 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.766 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.729 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.720 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=10, n_estimators=10;, score=0.750 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=10, n_estimators=10;, score=0.796 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=10, n_estimators=10;, score=0.720 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=10, n_estimators=10;, score=0.720 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=10, n_estimators=10;, score=0.729 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=10, n_estimators=50;, score=0.796 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=10, n_estimators=50;, score=0.722 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=10, n_estimators=50;, score=0.766 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=10, n_estimators=50;, score=0.720 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=10, n_estimators=50;, score=0.720 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=10, n_estimators=100;, score=0.806 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=10, n_estimators=100;, score=0.750 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=10, n_estimators=100;, score=0.757 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=10, n_estimators=100;, score=0.720 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=10, n_estimators=100;, score=0.710 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=10, n_estimators=200;, score=0.824 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=10, n_estimators=200;, score=0.741 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=10, n_estimators=200;, score=0.757 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=10, n_estimators=200;, score=0.720 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=10, n_estimators=200;, score=0.729 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=15, n_estimators=10;, score=0.750 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=15, n_estimators=10;, score=0.796 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=15, n_estimators=10;, score=0.692 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=15, n_estimators=10;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=15, n_estimators=10;, score=0.729 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=15, n_estimators=50;, score=0.787 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=15, n_estimators=50;, score=0.741 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=15, n_estimators=50;, score=0.794 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=15, n_estimators=50;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=15, n_estimators=50;, score=0.738 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=15, n_estimators=100;, score=0.778 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=15, n_estimators=100;, score=0.722 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=15, n_estimators=100;, score=0.757 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=15, n_estimators=100;, score=0.701 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=15, n_estimators=100;, score=0.729 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=15, n_estimators=200;, score=0.796 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=15, n_estimators=200;, score=0.741 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=15, n_estimators=200;, score=0.766 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=15, n_estimators=200;, score=0.720 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=15, n_estimators=200;, score=0.720 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=20, n_estimators=10;, score=0.750 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=20, n_estimators=10;, score=0.796 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=20, n_estimators=10;, score=0.692 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=20, n_estimators=10;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=20, n_estimators=10;, score=0.729 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=20, n_estimators=50;, score=0.787 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=20, n_estimators=50;, score=0.741 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=20, n_estimators=50;, score=0.794 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=20, n_estimators=50;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=20, n_estimators=50;, score=0.738 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=20, n_estimators=100;, score=0.778 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=20, n_estimators=100;, score=0.722 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=20, n_estimators=100;, score=0.757 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=20, n_estimators=100;, score=0.701 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=20, n_estimators=100;, score=0.729 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=20, n_estimators=200;, score=0.796 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=20, n_estimators=200;, score=0.741 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=20, n_estimators=200;, score=0.766 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=20, n_estimators=200;, score=0.720 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=20, n_estimators=200;, score=0.720 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=10;, score=0.648 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=10;, score=0.648 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=10;, score=0.654 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=10;, score=0.654 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=10;, score=0.645 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.759 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.741 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.738 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.720 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.769 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.759 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.766 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.701 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.748 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.796 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.769 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.766 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.701 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.738 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=10, n_estimators=10;, score=0.648 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=10, n_estimators=10;, score=0.648 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=10, n_estimators=10;, score=0.654 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=10, n_estimators=10;, score=0.654 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=10, n_estimators=10;, score=0.645 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=10, n_estimators=50;, score=0.787 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=10, n_estimators=50;, score=0.759 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=10, n_estimators=50;, score=0.692 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=10, n_estimators=50;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=10, n_estimators=50;, score=0.766 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=10, n_estimators=100;, score=0.759 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=10, n_estimators=100;, score=0.787 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=10, n_estimators=100;, score=0.710 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=10, n_estimators=100;, score=0.720 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=10, n_estimators=100;, score=0.766 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=10, n_estimators=200;, score=0.778 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=10, n_estimators=200;, score=0.769 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=10, n_estimators=200;, score=0.766 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=10, n_estimators=200;, score=0.710 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=10, n_estimators=200;, score=0.748 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=15, n_estimators=10;, score=0.648 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=15, n_estimators=10;, score=0.648 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=15, n_estimators=10;, score=0.654 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=15, n_estimators=10;, score=0.654 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=15, n_estimators=10;, score=0.645 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=15, n_estimators=50;, score=0.787 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=15, n_estimators=50;, score=0.759 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=15, n_estimators=50;, score=0.692 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=15, n_estimators=50;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=15, n_estimators=50;, score=0.766 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=15, n_estimators=100;, score=0.778 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=15, n_estimators=100;, score=0.787 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=15, n_estimators=100;, score=0.710 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=15, n_estimators=100;, score=0.729 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=15, n_estimators=100;, score=0.766 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=15, n_estimators=200;, score=0.778 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=15, n_estimators=200;, score=0.750 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=15, n_estimators=200;, score=0.785 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=15, n_estimators=200;, score=0.720 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=15, n_estimators=200;, score=0.738 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=20, n_estimators=10;, score=0.648 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=20, n_estimators=10;, score=0.648 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=20, n_estimators=10;, score=0.654 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=20, n_estimators=10;, score=0.654 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=20, n_estimators=10;, score=0.645 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=20, n_estimators=50;, score=0.787 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=20, n_estimators=50;, score=0.759 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=20, n_estimators=50;, score=0.692 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=20, n_estimators=50;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=20, n_estimators=50;, score=0.766 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=20, n_estimators=100;, score=0.778 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=20, n_estimators=100;, score=0.787 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=20, n_estimators=100;, score=0.710 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=20, n_estimators=100;, score=0.729 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=20, n_estimators=100;, score=0.766 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=20, n_estimators=200;, score=0.778 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=20, n_estimators=200;, score=0.750 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=20, n_estimators=200;, score=0.785 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=20, n_estimators=200;, score=0.720 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=20, n_estimators=200;, score=0.738 total time=   0.1s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=10;, score=0.648 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=10;, score=0.648 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=10;, score=0.654 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=10;, score=0.654 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=10;, score=0.645 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=50;, score=0.648 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=50;, score=0.648 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=50;, score=0.654 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=50;, score=0.654 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=50;, score=0.645 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=100;, score=0.648 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=100;, score=0.648 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=100;, score=0.654 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=100;, score=0.654 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=100;, score=0.645 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.648 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.648 total time=   0.1s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.654 total time=   0.1s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.654 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.645 total time=   0.1s
# [CV 1/5] END learning_rate=0.001, max_depth=10, n_estimators=10;, score=0.648 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_depth=10, n_estimators=10;, score=0.648 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_depth=10, n_estimators=10;, score=0.654 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_depth=10, n_estimators=10;, score=0.654 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_depth=10, n_estimators=10;, score=0.645 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_depth=10, n_estimators=50;, score=0.648 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_depth=10, n_estimators=50;, score=0.648 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_depth=10, n_estimators=50;, score=0.654 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_depth=10, n_estimators=50;, score=0.654 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_depth=10, n_estimators=50;, score=0.645 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_depth=10, n_estimators=100;, score=0.648 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_depth=10, n_estimators=100;, score=0.648 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_depth=10, n_estimators=100;, score=0.654 total time=   0.1s
# [CV 4/5] END learning_rate=0.001, max_depth=10, n_estimators=100;, score=0.654 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, max_depth=10, n_estimators=100;, score=0.645 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_depth=10, n_estimators=200;, score=0.648 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, max_depth=10, n_estimators=200;, score=0.648 total time=   0.1s
# [CV 3/5] END learning_rate=0.001, max_depth=10, n_estimators=200;, score=0.654 total time=   0.1s
# [CV 4/5] END learning_rate=0.001, max_depth=10, n_estimators=200;, score=0.654 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, max_depth=10, n_estimators=200;, score=0.645 total time=   0.1s
# [CV 1/5] END learning_rate=0.001, max_depth=15, n_estimators=10;, score=0.648 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_depth=15, n_estimators=10;, score=0.648 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_depth=15, n_estimators=10;, score=0.654 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_depth=15, n_estimators=10;, score=0.654 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_depth=15, n_estimators=10;, score=0.645 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_depth=15, n_estimators=50;, score=0.648 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_depth=15, n_estimators=50;, score=0.648 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_depth=15, n_estimators=50;, score=0.654 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_depth=15, n_estimators=50;, score=0.654 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_depth=15, n_estimators=50;, score=0.645 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_depth=15, n_estimators=100;, score=0.648 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, max_depth=15, n_estimators=100;, score=0.648 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_depth=15, n_estimators=100;, score=0.654 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_depth=15, n_estimators=100;, score=0.654 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, max_depth=15, n_estimators=100;, score=0.645 total time=   0.1s
# [CV 1/5] END learning_rate=0.001, max_depth=15, n_estimators=200;, score=0.648 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, max_depth=15, n_estimators=200;, score=0.648 total time=   0.1s
# [CV 3/5] END learning_rate=0.001, max_depth=15, n_estimators=200;, score=0.654 total time=   0.1s
# [CV 4/5] END learning_rate=0.001, max_depth=15, n_estimators=200;, score=0.654 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, max_depth=15, n_estimators=200;, score=0.645 total time=   0.1s
# [CV 1/5] END learning_rate=0.001, max_depth=20, n_estimators=10;, score=0.648 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_depth=20, n_estimators=10;, score=0.648 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_depth=20, n_estimators=10;, score=0.654 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_depth=20, n_estimators=10;, score=0.654 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_depth=20, n_estimators=10;, score=0.645 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_depth=20, n_estimators=50;, score=0.648 total time=   0.0s
# [CV 2/5] END learning_rate=0.001, max_depth=20, n_estimators=50;, score=0.648 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_depth=20, n_estimators=50;, score=0.654 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_depth=20, n_estimators=50;, score=0.654 total time=   0.0s
# [CV 5/5] END learning_rate=0.001, max_depth=20, n_estimators=50;, score=0.645 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_depth=20, n_estimators=100;, score=0.648 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, max_depth=20, n_estimators=100;, score=0.648 total time=   0.0s
# [CV 3/5] END learning_rate=0.001, max_depth=20, n_estimators=100;, score=0.654 total time=   0.0s
# [CV 4/5] END learning_rate=0.001, max_depth=20, n_estimators=100;, score=0.654 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, max_depth=20, n_estimators=100;, score=0.645 total time=   0.0s
# [CV 1/5] END learning_rate=0.001, max_depth=20, n_estimators=200;, score=0.648 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, max_depth=20, n_estimators=200;, score=0.648 total time=   0.1s
# [CV 3/5] END learning_rate=0.001, max_depth=20, n_estimators=200;, score=0.654 total time=   0.1s
# [CV 4/5] END learning_rate=0.001, max_depth=20, n_estimators=200;, score=0.654 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, max_depth=20, n_estimators=200;, score=0.645 total time=   0.1s
# GridSearchCV(estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_b...
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              param_grid={'learning_rate': [1, 0.5, 0.1, 0.01, 0.001],
#                          'max_depth': [5, 10, 15, 20],
#                          'n_estimators': [10, 50, 100, 200]},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 10}

# %%
xgb_hyper = XGBClassifier(learning_rate=1,max_depth=5,n_estimators=10)

# %%
xgb_hyper.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=10, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# accuracy after parameter's tuning
y_pred_new = xgb_hyper.predict(x_test)
prediction_y = [round(values) for values in y_pred_new]
accuracy = accuracy_score(y_pred_new,y_test)
accuracy
# Out:
# 0.7186147186147186

# %%
import pickle
filename = 'xgboost_model.pickle'
pickle.dump(xgb_hyper, open(filename, 'wb'))

loaded_model = pickle.load(open(filename, 'rb'))

# %%
# we'll save the scaler object as well for prediction
filename_scaler = 'scaler_model.pickle'
pickle.dump(ss, open(filename_scaler, 'wb'))

scaler_model = pickle.load(open(filename_scaler, 'rb'))

# %%
d=scaler_model.transform([[6,148,72,35,80,33.6,0.627,50]])
pred=loaded_model.predict(d)
print('This data belongs to class :',pred[0])
# Out:
# This data belongs to class : 1
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
