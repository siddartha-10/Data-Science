# %%
import numpy as np
import pandas as pd
import seaborn as sns
#import matplotlib.pyplot as plt
#%matplotlib inline

# %%
df = pd.DataFrame(np.random.randn(10,4),index=pd.date_range('1/1/2000',
   periods=10), columns=list('ABCD'))

# %%
df.head()
# Out:
#                    A         B         C         D
# 2000-01-01  0.952267 -1.491022  0.449531  0.815253
# 2000-01-02 -0.993054  0.100001 -0.322714 -0.225083
# 2000-01-03 -0.268173 -0.490791  0.139881 -0.216251
# 2000-01-04 -1.162937 -0.287551 -0.238041 -0.639968
# 2000-01-05  0.686451  0.324491 -1.681517 -0.161642

# %%
output=df['A'].plot()

# %%
import matplotlib.pyplot as plt
 
plt.savefig("output.jpg") #save as jpg
plt.savefig("output.png") #save as png

# %%
import numpy as np
from matplotlib import pyplot as plt
def sinplot(flip=1):
   x = np.linspace(0, 14, 100)
   for i in range(1, 5):
      plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
import seaborn as sb
sb.set_style("whitegrid")
sinplot()
plt.show()

# %%
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.522650  0.231294  0.605126  0.962917
# 1  0.802350  0.214527  0.400870  0.855334
# 2  0.994602  0.004477  0.625842  0.146249
# 3  0.606658  0.825660  0.043008  0.700023
# 4  0.478818  0.005290  0.954340  0.983461
# 5  0.251900  0.150378  0.401072  0.940666
# 6  0.430837  0.482029  0.011925  0.520061
# 7  0.965486  0.031530  0.351858  0.827874
# 8  0.033336  0.454902  0.170877  0.125148
# 9  0.558589  0.361462  0.116344  0.850929

# %%
df.plot.bar()

# %%
df.plot.barh(stacked=True)

# %%
df = pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':
np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

# %%
df
# Out:
#             a         b         c
# 0    0.086316 -0.328773 -0.082102
# 1   -0.598194  1.912153 -0.479606
# 2    0.983837  0.437140 -0.821180
# 3    0.447249  0.404288 -2.469749
# 4    1.567342 -0.795642  0.109060
# ..        ...       ...       ...
# 995  1.058824  1.194039 -1.729274
# 996  1.737798  0.083324 -1.901873
# 997 -0.006103 -0.640766  0.046529
# 998  3.101418  0.278584 -0.984229
# 999  1.940154  0.643712  0.138620
#
# [1000 rows x 3 columns]

# %%
df['a']
# Out:
# 0      0.086316
# 1     -0.598194
# 2      0.983837
# 3      0.447249
# 4      1.567342
#          ...
# 995    1.058824
# 996    1.737798
# 997   -0.006103
# 998    3.101418
# 999    1.940154
# Name: a, Length: 1000, dtype: float64

# %%
df['a'].plot.hist(bins=20)

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':
np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

df.plot.hist(bins=20)

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])

# %%
df
# Out:
#           A         B         C         D         E
# 0  0.738900  0.540714  0.348151  0.614007  0.456145
# 1  0.323811  0.431817  0.015682  0.018432  0.053224
# 2  0.964353  0.740476  0.221781  0.161812  0.239412
# 3  0.876871  0.176193  0.899557  0.579620  0.776517
# 4  0.010432  0.717020  0.122934  0.478048  0.491719
# 5  0.092023  0.405326  0.025629  0.848116  0.246895
# 6  0.316220  0.887934  0.653361  0.543772  0.225874
# 7  0.867517  0.086177  0.863315  0.812362  0.093121
# 8  0.858130  0.642483  0.018837  0.042465  0.434974
# 9  0.165820  0.251524  0.920575  0.112738  0.220876

# %%
df['A'].plot.box()

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.386573  0.838277  0.755110  0.809976
# 1  0.313880  0.376840  0.163983  0.289778
# 2  0.106103  0.342637  0.197943  0.460202
# 3  0.712264  0.952691  0.095898  0.176834
# 4  0.700439  0.225355  0.067625  0.320356
# 5  0.945451  0.100487  0.535889  0.445929
# 6  0.949839  0.122045  0.070586  0.214708
# 7  0.989110  0.438760  0.050133  0.893181
# 8  0.628974  0.622126  0.020701  0.256918
# 9  0.139918  0.642698  0.082577  0.803194

# %%
df['a'].plot.area()

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])

# %%
df.head()
# Out:
#           a         b         c         d
# 0  0.560490  0.866972  0.932968  0.754881
# 1  0.927802  0.405537  0.578435  0.370997
# 2  0.133837  0.758318  0.548384  0.240621
# 3  0.955933  0.639510  0.438004  0.541687
# 4  0.944962  0.988082  0.009383  0.726425

# %%
df.plot.scatter(x='a',y='b')

# %%
df = pd.DataFrame(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], columns=['x'])

# %%
df
# Out:
#           x
# a  0.827152
# b  2.444415
# c  2.393915
# d  2.671790

# %%
df.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001E983BA3D90>],
#       dtype=object)

# %% [markdown]
# ### matplotlib plotting

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.rand(4)
# Out:
# array([0.63974608, 0.13676078, 0.92216632, 0.22967261])

# %%
df = pd.DataFrame(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], columns=['x'])

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])

# %%
dataframe=pd.DataFrame(np.random.rand(50, 4),columns=['a', 'b', 'c', 'd'])

# %%
fig=plt.hist(dataframe)

# %%
plt.savefig("hist1.png")

# %%
plt.style.use()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-39f510d45dca> in <module>
# ----> 1 plt.style.use()
#
# TypeError: use() missing 1 required positional argument: 'style'

# %%
# make data
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
y
# Out:
# array([4.        , 4.40129771, 4.78627322, 5.13926821, 5.44592512,
#        5.69377113, 5.87272545, 5.97550938, 5.99794234, 5.9391119 ,
#        5.80141089, 5.59044011, 5.31478049, 4.98564409, 4.61641803,
#        4.22212008, 3.81878771, 3.42282588, 3.05033978, 2.71647972,
#        2.43482499, 2.21683149, 2.07136577, 2.00434444, 2.01849351,
#        2.11323748, 2.28472278, 2.52597448, 2.82718004, 3.17608834,
#        3.55850805, 3.95888481, 4.36093386, 4.74830246, 5.10523494,
#        5.4172136 , 5.67154914, 5.85789686, 5.96867732, 5.99938468,
#        5.94876998, 5.81889189, 5.61503301, 5.34548501, 5.02121136,
#        4.65540142, 4.26293398, 3.85977208, 3.46231375, 3.08672502,
#        2.74828243, 2.46075164, 2.23582754, 2.08265859, 2.00747471,
#        2.01333392, 2.09999787, 2.26394166, 2.4984971 , 2.79412399,
#        3.13879814, 3.51850042, 3.91778699, 4.32041746, 4.71001542,
#        5.07073453, 5.38790307, 5.64862067, 5.84228301, 5.96101317,
#        5.99998196, 5.95760439, 5.83560411, 5.63894329, 5.37562084,
#        5.056347  , 4.69410779, 4.30363675, 3.90081572, 3.50202887,
#        3.12349628, 2.7806142 , 2.48732886, 2.25556923, 2.09476179,
#        2.01144714, 2.009014  , 2.08756132, 2.24389431, 2.47165434,
#        2.76157762, 3.10187193, 3.47869629, 3.87672393, 4.27976564,
#        4.67142829, 5.03578156, 5.35800593, 5.62499538, 5.8258905 ])

# %%
plt.plot(x, y)

# %%
# plot
fig, ax = plt.subplots()

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
#plt.style.use('_mpl-gallery')

# make data
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)

# plot
fig, ax = plt.subplots(4)
print(ax)

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()
# Out:
# [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E9850C1C70>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9850B8FD0>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x000001E9851104F0>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x000001E985138C40>]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-104-ddd31be15d60> in <module>
#      12 print(ax)
#      13
# ---> 14 ax.plot(x, y, linewidth=2.0)
#      15
#      16 ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
fig=plt.figure('[10,10]')
ax=fig.add_axes([0,0,1,1])
lang=['Python','Java','C','C++']
stud=[50,40,30,20]
ax.bar(lang,stud)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
fig = plt.figure('[10,10]')
ax = fig.add_axes([0,0,1,1])
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]
ax.bar(langs,students)
plt.show()

# %%
plt.bar(langs,students)
# Out:
# <BarContainer object of 5 artists>

# %%
from matplotlib import pyplot as plt
import numpy as np
fig,ax = plt.subplots(1,1)
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
ax.hist(a, bins = [0,25,50,75,100])
ax.set_title("histogram of result")
ax.set_xticks([0,25,50,75,100])
ax.set_xlabel('marks')
ax.set_ylabel('no. of students')
plt.show()

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df.head()
# Out:
#                value
# 2019-06-07 -0.885932
# 2019-06-08 -0.754521
# 2019-06-09  0.300253
# 2019-06-10  1.070668
# 2019-06-11  0.693309

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07 -0.885932
# 2019-06-08 -1.640453
# 2019-06-09 -1.340201
# 2019-06-10 -0.269533
# 2019-06-11  0.423777

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07   -0.387222
# 2019-06-08   -1.347647
# 2019-06-09   -2.459893
# 2019-06-10   -3.243142
# 2019-06-11   -3.664882
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(5,5))

# %%
df.plot()

# %% [markdown]
# ### Seaborn plotting

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')

# %%
iris['sepal_length'].min()
# Out:
# 4.3

# %%
iris['sepal_length'].max()
# Out:
# 7.9

# %%
iris['sepal_length'].plot(kind='kde')

# %%
df = iris.drop(['species'], axis = 1)

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic['fare'].plot(kind='hist',figsize=(10,10),title="mygraph")

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0  0.518426  0.570848  0.469699  0.890312
# 1  0.148215  0.619890  0.791770  0.841569
# 2  0.262402  0.741843  0.384486  0.905550
# 3  0.894449  0.501142  0.352041  0.799834
# 4  0.799068  0.805014  0.653824  0.793143
# 5  0.089272  0.048587  0.544259  0.069777
# 6  0.794334  0.001410  0.621652  0.989271
# 7  0.427193  0.167422  0.125840  0.409620
# 8  0.348888  0.683506  0.385142  0.973998
# 9  0.153184  0.185231  0.033434  0.077169

# %%
df.plot.bar()

# %%
df.plot(kind = 'bar')

# %%
df.plot.barh()

# %%
iris.plot.hist()

# %%
iris.plot(kind = 'hist')

# %%
iris.plot(kind = 'hist', stacked = False, bins = 100)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
iris['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'b', alpha = 0.1, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E981AA2850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E981AC1610>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E981AEBCD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E981B20490>]],
#       dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
#df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
#df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10))

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a2f7d3f28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a2fa52e80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a2fa81320>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a303d2630>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a3040fcf8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a30662198>],
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
ts.plot.kde()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width]
# Index: []

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ec1ea58>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ecbcef0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a1faab240>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fad26a0>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()
